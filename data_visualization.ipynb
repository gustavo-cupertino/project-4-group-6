# %%
import pandas as pd

# %%
data_path = "../testing/Resources/data_cleaned.csv"

data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#   HeartDisease                         BMICategory Smoking AlcoholDrinking  \
# 0           No            Underweight (BMI < 18.5)     Yes              No
# 1           No  Normal weight (18.5 <= BMI < 25.0)      No              No
# 2           No     Overweight (25.0 <= BMI < 30.0)     Yes              No
# 3           No  Normal weight (18.5 <= BMI < 25.0)      No              No
# 4           No  Normal weight (18.5 <= BMI < 25.0)      No              No
#
#   Stroke DiffWalking     Sex  AgeCategory   Race Diabetic PhysicalActivity  \
# 0     No          No  Female        55-59  White      Yes              Yes
# 1    Yes          No  Female  80 or older  White       No              Yes
# 2     No          No    Male        65-69  White      Yes              Yes
# 3     No          No  Female        75-79  White       No               No
# 4     No         Yes  Female        40-44  White       No              Yes
#
#    GenHealth Asthma KidneyDisease SkinCancer
# 0  Very good    Yes            No        Yes
# 1  Very good     No            No         No
# 2       Fair    Yes            No         No
# 3       Good     No            No        Yes
# 4  Very good     No            No         No

# %%
import matplotlib.pyplot as plt
import numpy as np
import random as random

# %%
heart_disease = data["HeartDisease"].value_counts()
print(heart_disease)
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %%
heart_disease.index
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
heart_disease.values
# Out:
# array([292422,  27373])

# %%
plt.figure(figsize=[16,10])
plt.bar(heart_disease.index, heart_disease.values, align="center")

plt.xlabel ("Heart Disease")
plt.ylabel ("Number of occurrencies")

plt.savefig('plots/heart_disease.png', dpi=300)

# %%
sex = data["Sex"].value_counts()
print(sex)
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=[16,10])
plt.bar(sex.index, sex.values, align="center")

plt.xlabel ("Sex")
plt.ylabel ("Number of occurrencies")

plt.savefig('plots/sex.png', dpi=300)

# %%
age = data["AgeCategory"].value_counts()

# %%
plt.figure(figsize=[16,10])
plt.bar(age.index.sort_values(ascending=True), age.values, align="center")

plt.xlabel ("Age Category")
plt.ylabel ("Number of occurrencies")
plt.xticks(rotation=90)

plt.savefig('plots/age2.png', dpi=300)

# %%
race = data["Race"].value_counts()

# %%
plt.figure(figsize=[16,10])
plt.bar(race.index, race.values, align="center")
plt.xlabel ("Race")
plt.ylabel ("Number of occurrencies")
plt.xticks(rotation=45)

plt.savefig('plots/race.png', dpi=300)

# %%
health = data["GenHealth"].value_counts()
health
# Out:
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64

# %%
plt.figure(figsize=[16,10])
plt.bar(health.index, health.values, align="center")
plt.xlabel ("General health")
plt.ylabel ("Number of occurrencies")

plt.savefig('plots/health.png', dpi=300)

# %%
smoking = data["Smoking"].value_counts()

# %%
plt.figure(figsize=[16,10])
plt.bar(smoking.index, smoking.values, align="center")
plt.xlabel ("Smoking")
plt.ylabel ("Number of occurrencies")

plt.savefig('plots/smoking.png', dpi=300)

# %%
alcohol = data["AlcoholDrinking"].value_counts()

# %%
plt.figure(figsize=[16,10])
plt.bar(alcohol.index, alcohol.values, align="center")
plt.xlabel ("Alcohol drinking")
plt.ylabel ("Number of occurrencies")

plt.savefig('plots/alcohol.png', dpi=300)

# %%
BMICategory = data["BMICategory"].value_counts()

# %%
plt.figure(figsize=[16,10])
plt.bar(BMICategory.index, BMICategory.values, align="center")
plt.xlabel ("BMICategory")
plt.ylabel ("Number of occurrencies")
# plt.xticks(rotation=45)

plt.savefig('plots/BMICategory.png', dpi=300)
